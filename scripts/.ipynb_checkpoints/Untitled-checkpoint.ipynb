# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

df = pd.read_csv('../data/song_rankings_1993_to_2015.csv')

# %%
df.pivot_table
# Out:
#       Number                                              Title  \
# 0          1                                            Asshole
# 1          2                                              Creep
# 2          3                                             Linger
# 3          4                                            No Rain
# 4          5                                         Cannonball
# 5          6                                Killing In The Name
# 6          7                                              Lemon
# 7          8                                                 Go
# 8          9                              The Honeymoon Is Over
# 9         10                           Stone Me Into The Groove
# 10        11                                    Everybody Hurts
# 11        12                                              Plush
# 12        13                                    Soul To Squeeze
# 13        14                       I Held Her In My Arms (1993)
# 14        15                                       Wild America
# 15        16                                      Sister Havana
# 16        17                                 Hits From The Bong
# 17        18                                            Go West
# 18        19                        Trout (feat. Michael Stipe)
# 19        20                                   Heart-Shaped Box
# 20        21                                        Black Stick
# 21        22                               The Ship Song (Live)
# 22        23                                    Human Behaviour
# 23        24                                         What's Up?
# 24        25                                      Feed The Tree
# 25        26                                          Somewhere
# 26        27                                              Sober
# 27        28                            Are You Gonna Go My Way
# 28        29                                 All That She Wants
# 29        30                                   Constant Craving
# ...      ...                                                ...
# 2271      71                                Flesh Without Blood
# 2272      72                                             Anchor
# 2273      73                                  Once (Radio Edit)
# 2274      74   Powerful (feat. Ellie Goulding &   Tarrus Riley)
# 2275      75                                  Elevator Operator
# 2276      76                                           Suddenly
# 2277      77                                           Lay Down
# 2278      78                                          Weathered
# 2279      79                                             Wolves
# 2280      80  Everyday (feat. Rod Stewart, Miguel &   Mark R...
# 2281      81                  Big Jet Plane (feat. Thelma Plum)
# 2282      82                                          Depreston
# 2283      83                                      Down To Earth
# 2284      84                                             Delete
# 2285      85                      Heart Attack (feat. Owl Eyes)
# 2286      86                                         Happy Song
# 2287      87                                        Begin Again
# 2288      88                                      Party Machine
# 2289      89                                  High By The Beach
# 2290      90                        Gemini (feat. George Maple)
# 2291      91                                     Be Your Shadow
# 2292      92                         No One (feat. Thelma Plum)
# 2293      93                                      Indian Summer
# 2294      94                                              Ghost
# 2295      95  Nobody Really Cares If You Don't Go To   The P...
# 2296      96      Rumour Mill (feat. Anne-Marie & Will   Heard)
# 2297      97                                   Twilight Driving
# 2298      98                     Be Together (feat. Wild Belle)
# 2299      99                                       True Friends
# 2300     100                                           Hell Boy
#
#                          Artist  Time    Country  Year
# 0                   Denis Leary  4:28        USA  1993
# 1                     Radiohead  3:56    England  1993
# 2               The Cranberries  4:34    Ireland  1993
# 3                   Blind Melon  3:37        USA  1993
# 4                  The Breeders  3:37        USA  1993
# 5      Rage Against The Machine  5:14        USA  1993
# 6                            U2  6:58    Ireland  1993
# 7                     Pearl Jam  3:13        USA  1993
# 8                 The Cruel Sea  3:07  Australia  1993
# 9                  Atomic Swing  4:06     Sweden  1993
# 10                       R.E.M.  5:19        USA  1993
# 11          Stone Temple Pilots  5:14        USA  1993
# 12        Red Hot Chili Peppers  4:50        USA  1993
# 13               Violent Femmes  3:03        USA  1993
# 14                     Iggy Pop  5:47        USA  1993
# 15                Urge Overkill  3:51        USA  1993
# 16                 Cypress Hill  2:41        USA  1993
# 17                Pet Shop Boys  5:00    England  1993
# 18                 Neneh Cherry  5:06     Sweden  1993
# 19                      Nirvana  4:42        USA  1993
# 20                The Cruel Sea  5:02  Australia  1993
# 21    Nick Cave & The Bad Seeds  4:23  Australia  1993
# 22                        Björk  4:13    Iceland  1993
# 23                4 Non Blondes  4:56        USA  1993
# 24                        Belly  3:29        USA  1993
# 25                         Efua  4:13    England  1993
# 26                         Tool  5:06        USA  1993
# 27                Lenny Kravitz  3:31        USA  1993
# 28                  Ace Of Base  3:33     Sweden  1993
# 29                    k.d. lang  4:39     Canada  1993
# ...                         ...   ...        ...   ...
# 2271                     Grimes  4:25     Canada  2015
# 2272             Birds Of Tokyo  3:36  Australia  2015
# 2273                    Ngaiire  4:27  Australia  2015
# 2274                Major Lazer  3:26        USA  2015
# 2275           Courtney Barnett  3:15  Australia  2015
# 2276              British India  4:28  Australia  2015
# 2277                      DMA'S  3:15  Australia  2015
# 2278               Jack Garratt  4:34    England  2015
# 2279             The Cat Empire  3:23  Australia  2015
# 2280                 A$AP Rocky  4:21        USA  2015
# 2281                       Tuka  3:34  Australia  2015
# 2282           Courtney Barnett  4:53  Australia  2015
# 2283          Flight Facilities  4:30  Australia  2015
# 2284             Sticky Fingers  4:22  Australia  2015
# 2285          Flight Facilities  6:28  Australia  2015
# 2286       Bring Me The Horizon  3:59    England  2015
# 2287                Purity Ring  3:37     Canada  2015
# 2288                The Bennies  2:45  Australia  2015
# 2289               Lana Del Rey  4:18        USA  2015
# 2290                What So Not  4:30  Australia  2015
# 2291                The Wombats  3:36    England  2015
# 2292            Golden Features  4:55  Australia  2015
# 2293                   Jai Wolf  4:09        USA  2015
# 2294                     Halsey  2:34        USA  2015
# 2295           Courtney Barnett  2:46  Australia  2015
# 2296                 Rudimental  4:04    England  2015
# 2297               Methyl Ethel  3:59  Australia  2015
# 2298                Major Lazer  3:53        USA  2015
# 2299       Bring Me The Horizon  3:52    England  2015
# 2300                Seth Sentry  3:24  Australia  2015
#
# [2301 rows x 6 columns]

# %%
df2.pivot(columns='Country')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-7a16e699c06e> in <module>()
# ----> 1 df2.pivot(columns='Country')
#
# /Users/willemolding/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in pivot(self, index, columns, values)
#    3507         """
#    3508         from pandas.core.reshape import pivot
# -> 3509         return pivot(self, index=index, columns=columns, values=values)
#    3510
#    3511     def stack(self, level=-1, dropna=True):
#
# /Users/willemolding/anaconda/lib/python2.7/site-packages/pandas/core/reshape.pyc in pivot(self, index, columns, values)
#     320     """
#     321     if values is None:
# --> 322         indexed = self.set_index([index, columns])
#     323         return indexed.unstack(columns)
#     324     else:
#
# /Users/willemolding/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2605                 names.append(None)
#    2606             else:
# -> 2607                 level = frame[col].values
#    2608                 names.append(col)
#    2609                 if drop:
#
# /Users/willemolding/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /Users/willemolding/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /Users/willemolding/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1082         res = cache.get(item)
#    1083         if res is None:
# -> 1084             values = self._data.get(item)
#    1085             res = self._box_item_values(item, values)
#    1086             cache[item] = res
#
# /Users/willemolding/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    2858                         loc = indexer.item()
#    2859                     else:
# -> 2860                         raise ValueError("cannot label index with a null key")
#    2861
#    2862             return self.iget(loc, fastpath=fastpath)
#
# ValueError: cannot label index with a null key
